# %%
# %pip install -r requirements.txt
dbutils.library.restartPython()

# %%
import helpers
import config
from jobs import extract_industries, screener_etl, zerodha_etl

drive_service, sheet_service, gc = helpers.get_services()
extract_industries.run()
screener_etl.run(gc)
zerodha_etl.run(helpers,drive_service, sheet_service, gc)
